# %% [markdown]
# <a href="https://colab.research.google.com/github/kanyaweeud/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import os for file manipulation
import os
# import pandas for tabular or dataframe management
import pandas as pd
# create variable for path to thr folder that stores our data
base_path = '/content/drive/My Drive/DWDM_Material'
# load data from test.csv to data
data = pd.read_csv(os.path.join(base_path,'test.csv'))
# show head of the data table
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# # Box plot

# %% [markdown]
# >>>> หาการกระจาย หา out liner

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['y'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff399faf0b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff399fafac8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff399f3d588>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff399f3d208>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff399faf3c8>,
#   <matplotlib.lines.Line2D at 0x7ff399faf748>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff399a75208>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff399a75c18>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff399a826d8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff399a82358>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff399a75518>,
#   <matplotlib.lines.Line2D at 0x7ff399a75898>]}

# %% [markdown]
# ^ vert เปลี่ยนแนวตั้งเป็นนอน

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff399f1a908>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff399f01ef0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff399a2d4a8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff399aa2048>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff399a82898>,
#   <matplotlib.lines.Line2D at 0x7ff399a91470>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %% [markdown]
# ^ ต้อง get x เพราะแนวนอนเป็นแกน x

# %%
oput['fliers'][0]

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=25)

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='y')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='P')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='1')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='p',alpha=0.4)
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6)

# %% [markdown]
# # HW4 วาดปีกกับนอไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k')
plt.scatter([32,30,28,26,24,22,20,22,24,26,28,30,32,34,36,38,40,84,84,86,88,90,92,94,96,98,98,96,96,94,92,90,88,86,84,82,80,80,80,80,80,80],[81,83,85,87,91,93,95,94,94,94,94,94,94,94,94,94,94,35,38,41,44,47,50,53,56,59,63,68,72,75,74,71,68,65,61,58,54,50,46,42,38,35],s=50,alpha=1)
